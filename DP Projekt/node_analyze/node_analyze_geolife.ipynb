# %% [markdown]
# Import

# %%
import json
from collections import defaultdict
import pandas as pd
from tqdm import tqdm
from haversine import haversine

# %% [markdown]
# Load data

# %%
# Load data from the CSV file into a new DataFrame
data = pd.read_csv('../model/gps_data.csv')

# %% [markdown]
# Extract nodes

# %%
unique_taxi_ids = data['Person ID'].unique()
unique_taxi_ids_df = pd.DataFrame({'Person ID': unique_taxi_ids})
unique_taxi_ids_df.to_csv('../files/nodes/geolife.csv', index=False)

# %%
def calculate_distance(coord1, coord2):
	return haversine(coord1, coord2)

# %% [markdown]
# Save close coordinates

# %%
meeting_points = defaultdict(list)
meeting_distance_threshold = 0.1
meeting_info_list = []

for index, row in tqdm(data.iterrows(), desc="main data"):
	taxi_id = row["Person ID"]
	location = (row["Latitude"], row["Longitude"])

	if meeting_points[location]:
		for other_taxi_id in meeting_points[location]:
			if taxi_id != other_taxi_id:
				other_location = (data.loc[data["Person ID"] == other_taxi_id, "Latitude"].iloc[0], data.loc[data["Person ID"] == other_taxi_id, "Longitude"].iloc[0])

				distance = calculate_distance(location, other_location)
				if distance <= meeting_distance_threshold:
					meeting_info = {
						"Taxi1": int(other_taxi_id),
						"Taxi2": int(taxi_id),
						"Location": {
							"Latitude": location[0],
							"Longitude": location[1]
						},
						"Distance (meters)": distance,
						"Timestamp1": row["Timestamp"],
						"Timestamp2": data.loc[data["Person ID"] == other_taxi_id, "Timestamp"].iloc[0]
					}

					meeting_info_list.append(meeting_info)
                      
	meeting_points[location].extend([taxi_id])
# Out:
# main data: 752856it [10:13, 1226.33it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#      10 for other_taxi_id in meeting_points[location]:
#      11 	if taxi_id != other_taxi_id:
# ---> 12 		other_location = (data.loc[data["Person ID"] == other_taxi_id, "Latitude"].iloc[0], data.loc[data["Person ID"] == other_taxi_id, "Longitude"].iloc[0])
#      14 		distance = calculate_distance(location, other_location)
#      15 		if distance <= meeting_distance_threshold:
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:349, in comparison_op(left, right, op)
#     346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
# --> 349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     351 return res_values
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     217     func = partial(expressions.evaluate, op)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     239 if op_str is not None:
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\danstorm\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      71 if _TEST_MODE:
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# KeyboardInterrupt:

# %% [markdown]
# Save into a file

# %%
with open('../files/edges/geolife.json', 'w') as json_file:
	json.dump(meeting_info_list, json_file, indent=4)
